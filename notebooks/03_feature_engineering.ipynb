# %%
import sys; sys.path.append("..")
import pandas as pd
import numpy as np

df = pd.read_csv("../data/processed/credit_default_clean.csv")
df.shape
# Out:
# (29964, 24)

# %%
from src.features import add_features

df_feat = add_features(df)
print(df_feat.shape)
print(df_feat[["avg_delay", "max_delay", "delay_trend",
                "avg_util_ratio", "avg_pay_ratio"]].describe().round(3))
# Out:
# (29964, 41)
#        avg_delay  max_delay  delay_trend  avg_util_ratio  avg_pay_ratio
# count   29964.00  29964.000    29964.000       29964.000      29964.000
# mean       -0.58      0.017        0.254           0.373          0.446
# std         0.85      1.511        1.217           0.352          0.628
# min        -1.00     -1.000       -7.000          -0.233          0.000
# 25%        -1.00     -1.000        0.000           0.030          0.040
# 50%        -1.00     -1.000        0.000           0.286          0.078
# 75%        -0.50      2.000        0.000           0.688          0.836
# max         6.00      8.000        7.000           5.364          5.000

# %%
for col in ["avg_delay", "max_delay", "delay_trend", "avg_util_ratio", "avg_pay_ratio"]:
    corr = df_feat[col].corr(df_feat["default"])
    print(f"{col}: correlation with default = {corr:.3f}")
# Out:
# avg_delay: correlation with default = 0.387
# max_delay: correlation with default = 0.374
# delay_trend: correlation with default = 0.170
# avg_util_ratio: correlation with default = 0.115
# avg_pay_ratio: correlation with default = -0.120

# %%
df.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    29964.000000  29964.000000  29964.000000  29964.000000  29964.000000
# mean    167441.585903      1.603724      1.842711      1.557302     35.487652
# std     129762.280262      0.489131      0.744495      0.521430      9.219449
# min      10000.000000      1.000000      1.000000      1.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      4.000000      3.000000     79.000000
#
#               PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  29964.000000  29964.000000  29964.000000  29964.000000  29964.000000
# mean      -0.416767     -0.531571     -0.555133     -0.623949     -0.679349
# ...

# %%
df_feat.to_csv("../data/processed/credit_default_features.csv", index=False)
print("saved:", df_feat.shape)
# Out:
# saved: (29964, 41)
